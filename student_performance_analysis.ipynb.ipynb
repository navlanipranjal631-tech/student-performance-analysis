# %%
df = pd.read_csv("student_data.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B                    bachelor      standard
# 1    male        group C                some college  free/reduced
# 2  female        group B                      master      standard
# 3    male        group A                 high school      standard
# 4  female        group C                   associate  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          47             57             44
# 2               completed          69             90             88
# 3                    none          58             54             52
# 4               completed          88             95             92

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       10 non-null     object
#  1   race/ethnicity               10 non-null     object
#  2   parental level of education  10 non-null     object
#  3   lunch                        10 non-null     object
#  4   test preparation course      10 non-null     object
#  5   math score                   10 non-null     int64
#  6   reading score                10 non-null     int64
#  7   writing score                10 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 772.0+ bytes
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# ...

# %%
import pandas as pd

# Create dataset
data = {
    "gender": ["female","male","female","male","female","male","female","male","female","male"],
    "race/ethnicity": ["group B","group C","group B","group A","group C","group B","group A","group C","group B","group A"],
    "parental level of education": ["bachelor","some college","master","high school","associate","bachelor","high school","associate","master","some college"],
    "lunch": ["standard","free/reduced","standard","standard","free/reduced","standard","free/reduced","standard","standard","free/reduced"],
    "test preparation course": ["none","completed","completed","none","completed","none","none","completed","completed","none"],
    "math score": [72,47,69,58,88,76,50,65,90,45],
    "reading score": [72,57,90,54,95,78,60,70,92,50],
    "writing score": [74,44,88,52,92,75,58,68,94,48]
}

df = pd.DataFrame(data)

# Save as CSV
df.to_csv("student_data.csv", index=False)

df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B                    bachelor      standard
# 1    male        group C                some college  free/reduced
# 2  female        group B                      master      standard
# 3    male        group A                 high school      standard
# 4  female        group C                   associate  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          47             57             44
# 2               completed          69             90             88
# 3                    none          58             54             52
# 4               completed          88             95             92

# %%
import matplotlib.pyplot as plt

plt.hist(df["math score"])
plt.title("Math Score Distribution")
plt.show()
